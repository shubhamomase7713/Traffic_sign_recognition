# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/DBDA_PROJECT/Total.csv")

# %%
df
# Out:
#      class   accuraccy  precision    recall        f1  support  \
# 0        0  100.000000   0.993617  1.000000  0.996798      467
# 1        1   94.004796   0.990123  0.961631  0.975669      417
# 2        2  100.000000   0.993521  0.995671  0.994595      462
# 3        3   98.623853   0.995402  0.993119  0.994259      436
# 4        4   99.782135   1.000000  1.000000  1.000000      459
# ..     ...         ...        ...       ...       ...      ...
# 511     38   97.849462   0.918635  0.940860  0.929615      372
# 512     39  100.000000   0.914894  0.977273  0.945055       88
# 513     40   87.577640   0.949405  0.990683  0.969605      322
# 514     41   95.925926   0.931900  0.962963  0.947177      270
# 515     42   98.571429   0.982332  0.992857  0.987567      280
#
#                          model
# 0       balanced_SMOTE_CNN.csv
# 1       balanced_SMOTE_CNN.csv
# 2       balanced_SMOTE_CNN.csv
# 3       balanced_SMOTE_CNN.csv
# 4       balanced_SMOTE_CNN.csv
# ...

# %%
df['total'] = df['accuraccy']+df['precision'] + df['recall'] + df['f1']

# %%
df.total = df.total.round(4)

# %%
df.groupby('class',sort=False)['total'].max()
# Out:
# class
# 0     103.0000
# 1     101.4107
# 2     102.9966
# 3     102.9320
# 4     103.0000
# 5     103.0000
# 6     103.0000
# 7     102.9874
# 8     103.0000
# 9     103.0000
# 10    102.9394
# 11    103.0000
# 12    102.5297
# 13    102.4582
# 14    102.9809
# 15    103.0000
# 16    102.9876
# 17    103.0000
# 18    102.9717
# 19    102.7836
# 20    102.9966
# 21    103.0000
# 22    102.9894
# 23    102.9535
# 24    102.9938
# 25    102.9800
# 26    103.0000
# 27    103.0000
# 28    103.0000
# 29    103.0000
# 30    103.0000
# 31    103.0000
# 32    103.0000
# 33    103.0000
# 34    102.9849
# 35    103.0000
# 36    103.0000
# 37    103.0000
# 38    102.9154
# 39    103.0000
# 40    102.5217
# 41    102.8630
# 42    102.9935
# Name: total, dtype: float64

# %%
df0=df[(df['class']==0) & (df['total']==df['total'].max())].iloc[:,0:7]
df0
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 301      0      100.0        1.0     1.0  1.0       36
#
#                          model
# 301  balanced_wt_ResNet_50.csv

# %%
# df1=df[(df['class']==1) & (df['total']==z[1].max())].iloc[:,0:8]
# df1

# %%
df1=df[(df['class']==1) & (df['total']==101.4107)].iloc[:,0:7]
df1
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 173      1  98.526316   0.952479  0.970526  0.961418      475
#
#                            model
# 173  balanced_tk_ResNet50_50.csv

# %%
df2=df[(df['class']==2) & (df['total']==102.9966)].iloc[:,0:7]
df2
# Out:
#      class  accuraccy  precision  recall        f1  support  \
# 432      2      100.0   0.997727     1.0  0.998862      439
#
#                          model
# 432  imbalanced_resnet_L50.csv

# %%
df3=df[(df['class']==3) & (df['total']==102.9320)].iloc[:,0:7]
df3
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 175      3      100.0   0.958801  0.996109  0.977099      257
#
#                            model
# 175  balanced_tk_ResNet50_50.csv

# %%
df4=df[(df['class']==4) & (df['total']==df['total'].max())].iloc[:,0:7]
df4
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 305      4      100.0        1.0     1.0  1.0      421
# 434      4      100.0        1.0     1.0  1.0      421
#
#                          model
# 305  balanced_wt_ResNet_50.csv
# 434  imbalanced_resnet_L50.csv

# %%
df5=df[(df['class']==5) & (df['total']==df['total'].max())].iloc[:,0:7]
df5
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 306      5      100.0        1.0     1.0  1.0      432
#
#                          model
# 306  balanced_wt_ResNet_50.csv

# %%
df6=df[(df['class']==6) & (df['total']==df['total'].max())].iloc[:,0:7]
df6
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 92       6      100.0        1.0     1.0  1.0      475
# 135      6      100.0        1.0     1.0  1.0      169
# 221      6      100.0        1.0     1.0  1.0      169
# 307      6      100.0        1.0     1.0  1.0      162
# 393      6      100.0        1.0     1.0  1.0      162
#
#                              model
# 92   balanced_SMOTE_ResNet_152.csv
# 135            balanced_tk_cnn.csv
# 221   balanced_tk_ResNet50_152.csv
# 307      balanced_wt_ResNet_50.csv
# 393             imbalanced_cnn.csv

# %%
df7=df[(df['class']==7) & (df['total']==102.9874)].iloc[:,0:7]
df7
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 136      7      100.0        1.0  0.991597  0.995781      119
#
#                    model
# 136  balanced_tk_cnn.csv

# %%
df8=df[(df['class']==8) & (df['total']==df['total'].max())].iloc[:,0:7]
df8
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 8        8      100.0        1.0     1.0  1.0      467
# 223      8      100.0        1.0     1.0  1.0       88
# 309      8      100.0        1.0     1.0  1.0       81
# 438      8      100.0        1.0     1.0  1.0       81
#
#                             model
# 8          balanced_SMOTE_CNN.csv
# 223  balanced_tk_ResNet50_152.csv
# 309     balanced_wt_ResNet_50.csv
# 438     imbalanced_resnet_L50.csv

# %%
df9=df[(df['class']==9) & (df['total']==df['total'].max())].iloc[:,0:7]
df9
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 138      9      100.0        1.0     1.0  1.0      241
# 310      9      100.0        1.0     1.0  1.0      227
# 396      9      100.0        1.0     1.0  1.0      227
#
#                          model
# 138        balanced_tk_cnn.csv
# 310  balanced_wt_ResNet_50.csv
# 396         imbalanced_cnn.csv

# %%
df10=df[(df['class']==10) & (df['total']==102.9394)].iloc[:,0:7]
df10
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 182     10      100.0   0.987755  0.971888  0.979757      249
#
#                            model
# 182  balanced_tk_ResNet50_50.csv

# %%
df11=df[(df['class']==11) & (df['total']==df['total'].max())].iloc[:,0:7]
df11
# Out:
#      class  accuraccy  precision  recall   f1  support                model
# 140     11      100.0        1.0     1.0  1.0       34  balanced_tk_cnn.csv

# %%
df12=df[(df['class']==12) & (df['total']==102.5297)].iloc[:,0:7]
df12
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 313     12  99.559471    0.99117  0.988987  0.990077      454
#
#                          model
# 313  balanced_wt_ResNet_50.csv

# %%
df13=df[(df['class']==13) & (df['total']==102.4582)].iloc[:,0:7]
df13
# Out:
#     class  accuraccy  precision    recall        f1  support  \
# 56     13  99.529412   0.997543  0.955294  0.975962      425
#
#                            model
# 56  balanced_SMOTE_ResNet_50.csv

# %%
df14=df[(df['class']==14) & (df['total']==102.9809)].iloc[:,0:7]
df14
# Out:
#      class  accuraccy  precision  recall        f1  support  \
# 100     14      100.0   0.987288     1.0  0.993603      466
#
#                              model
# 100  balanced_SMOTE_ResNet_152.csv

# %%
df15=df[(df['class']==15) & (df['total']==df['total'].max())].iloc[:,0:7]
df15
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 58      15      100.0        1.0     1.0  1.0      449
# 101     15      100.0        1.0     1.0  1.0      449
# 316     15      100.0        1.0     1.0  1.0       82
# 402     15      100.0        1.0     1.0  1.0       82
# 445     15      100.0        1.0     1.0  1.0       82
#
#                              model
# 58    balanced_SMOTE_ResNet_50.csv
# 101  balanced_SMOTE_ResNet_152.csv
# 316      balanced_wt_ResNet_50.csv
# 402             imbalanced_cnn.csv
# 445      imbalanced_resnet_L50.csv

# %%
df16=df[(df['class']==16) & (df['total']==102.9876)].iloc[:,0:7]
df16
# Out:
#     class  accuraccy  precision    recall        f1  support  \
# 16     16      100.0   0.995868  0.995868  0.995868      484
#
#                      model
# 16  balanced_SMOTE_CNN.csv

# %%
df17=df[(df['class']==17) & (df['total']==df['total'].max())].iloc[:,0:7]
df17
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 318     17      100.0        1.0     1.0  1.0       53
#
#                          model
# 318  balanced_wt_ResNet_50.csv

# %%
df18=df[(df['class']==18) & (df['total']==102.9717)].iloc[:,0:7]
df18
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 147     18      100.0   0.996198  0.984962  0.990548      266
#
#                    model
# 147  balanced_tk_cnn.csv

# %%
df19=df[(df['class']==19) & (df['total']==102.7836)].iloc[:,0:7]
df19
# Out:
#     class  accuraccy  precision    recall     f1  support  \
# 62     19      100.0   0.992683  0.865957  0.925      470
#
#                            model
# 62  balanced_SMOTE_ResNet_50.csv

# %%
df20=df[(df['class']==20) & (df['total']==102.9966)].iloc[:,0:7]
df20
# Out:
#     class  accuraccy  precision  recall        f1  support  \
# 20     20      100.0   0.997701     1.0  0.998849      434
#
#                      model
# 20  balanced_SMOTE_CNN.csv

# %%
df21=df[(df['class']==21) & (df['total']==df['total'].max())].iloc[:,0:7]
df21
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 322     21      100.0        1.0     1.0  1.0      100
# 408     21      100.0        1.0     1.0  1.0      100
#
#                          model
# 322  balanced_wt_ResNet_50.csv
# 408         imbalanced_cnn.csv

# %%
df22=df[(df['class']==22) & (df['total']==102.9894)].iloc[:,0:7]
df22
# Out:
#     class  accuraccy  precision    recall        f1  support  \
# 65     22      100.0   0.997642  0.995294  0.996466      425
#
#                            model
# 65  balanced_SMOTE_ResNet_50.csv

# %%
df23=df[(df['class']==23) & (df['total']==102.9535)].iloc[:,0:7]
df23
# Out:
#     class  accuraccy  precision    recall       f1  support  \
# 23     23      100.0   0.973568  0.995495  0.98441      444
#
#                      model
# 23  balanced_SMOTE_CNN.csv

# %%
df24=df[(df['class']==24) & (df['total']==102.9938)].iloc[:,0:7]
df24
# Out:
#     class  accuraccy  precision    recall        f1  support  \
# 24     24      100.0        1.0  0.995876  0.997934      485
#
#                      model
# 24  balanced_SMOTE_CNN.csv

# %%
df25=df[(df['class']==25) & (df['total']==102.9800)].iloc[:,0:7]
df25
# Out:
#     class  accuraccy  precision    recall        f1  support  \
# 25     25      100.0   0.988938  0.997768  0.993333      448
#
#                      model
# 25  balanced_SMOTE_CNN.csv

# %%
df26=df[(df['class']==26) & (df['total']==df['total'].max())].iloc[:,0:7]
df26
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 26      26      100.0        1.0     1.0  1.0      442
# 69      26      100.0        1.0     1.0  1.0      442
# 327     26      100.0        1.0     1.0  1.0       40
# 413     26      100.0        1.0     1.0  1.0       40
# 456     26      100.0        1.0     1.0  1.0       40
#
#                             model
# 26         balanced_SMOTE_CNN.csv
# 69   balanced_SMOTE_ResNet_50.csv
# 327     balanced_wt_ResNet_50.csv
# 413            imbalanced_cnn.csv
# 456     imbalanced_resnet_L50.csv

# %%
df27=df[(df['class']==27) & (df['total']==df['total'].max())].iloc[:,0:7]
df27
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 199     27      100.0        1.0     1.0  1.0      153
# 328     27      100.0        1.0     1.0  1.0      137
# 414     27      100.0        1.0     1.0  1.0      137
#
#                            model
# 199  balanced_tk_ResNet50_50.csv
# 328    balanced_wt_ResNet_50.csv
# 414           imbalanced_cnn.csv

# %%
df28=df[(df['class']==28) & (df['total']==df['total'].max())].iloc[:,0:7]
df28
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 286     28      100.0        1.0     1.0  1.0       83
# 329     28      100.0        1.0     1.0  1.0       83
# 458     28      100.0        1.0     1.0  1.0       83
# 501     28      100.0        1.0     1.0  1.0       83
#
#                          model
# 286        balanced_WT_cnn.csv
# 329  balanced_wt_ResNet_50.csv
# 458  imbalanced_resnet_L50.csv
# 501  imbalanced_RESNET_152.csv

# %%
df29=df[(df['class']==29) & (df['total']==df['total'].max())].iloc[:,0:7]
df29
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 29      29      100.0        1.0     1.0  1.0      480
# 330     29      100.0        1.0     1.0  1.0      222
#
#                          model
# 29      balanced_SMOTE_CNN.csv
# 330  balanced_wt_ResNet_50.csv

# %%
df30=df[(df['class']==30) & (df['total']==df['total'].max())].iloc[:,0:7]
df30
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 30      30      100.0        1.0     1.0  1.0      441
# 331     30      100.0        1.0     1.0  1.0       62
# 417     30      100.0        1.0     1.0  1.0       62
# 460     30      100.0        1.0     1.0  1.0       62
# 503     30      100.0        1.0     1.0  1.0       62
#
#                          model
# 30      balanced_SMOTE_CNN.csv
# 331  balanced_wt_ResNet_50.csv
# 417         imbalanced_cnn.csv
# 460  imbalanced_resnet_L50.csv
# 503  imbalanced_RESNET_152.csv

# %%
df31=df[(df['class']==31) & (df['total']==df['total'].max())].iloc[:,0:7]
df31
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 117     31      100.0        1.0     1.0  1.0      456
# 160     31      100.0        1.0     1.0  1.0       42
# 203     31      100.0        1.0     1.0  1.0       42
# 246     31      100.0        1.0     1.0  1.0       42
# 289     31      100.0        1.0     1.0  1.0       47
# 332     31      100.0        1.0     1.0  1.0       47
# 418     31      100.0        1.0     1.0  1.0       47
# 504     31      100.0        1.0     1.0  1.0       47
#
#                              model
# 117  balanced_SMOTE_ResNet_152.csv
# 160            balanced_tk_cnn.csv
# 203    balanced_tk_ResNet50_50.csv
# 246   balanced_tk_ResNet50_152.csv
# 289            balanced_WT_cnn.csv
# 332      balanced_wt_ResNet_50.csv
# 418             imbalanced_cnn.csv
# 504      imbalanced_RESNET_152.csv

# %%
df32=df[(df['class']==32) & (df['total']==df['total'].max())].iloc[:,0:7]
df32
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 32      32      100.0        1.0     1.0  1.0      458
# 333     32      100.0        1.0     1.0  1.0      399
#
#                          model
# 32      balanced_SMOTE_CNN.csv
# 333  balanced_wt_ResNet_50.csv

# %%
df33=df[(df['class']==33) & (df['total']==df['total'].max())].iloc[:,0:7]
df33
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 76      33      100.0        1.0     1.0  1.0      471
# 162     33      100.0        1.0     1.0  1.0       56
# 205     33      100.0        1.0     1.0  1.0       56
# 291     33      100.0        1.0     1.0  1.0       68
# 334     33      100.0        1.0     1.0  1.0       68
# 463     33      100.0        1.0     1.0  1.0       68
#
#                             model
# 76   balanced_SMOTE_ResNet_50.csv
# 162           balanced_tk_cnn.csv
# 205   balanced_tk_ResNet50_50.csv
# 291           balanced_WT_cnn.csv
# 334     balanced_wt_ResNet_50.csv
# 463     imbalanced_resnet_L50.csv

# %%
df34=df[(df['class']==34) & (df['total']==102.9849)].iloc[:,0:7]
df34
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 335     34      100.0   0.992443  0.997468  0.994949      395
#
#                          model
# 335  balanced_wt_ResNet_50.csv

# %%
df35=df[(df['class']==35) & (df['total']==df['total'].max())].iloc[:,0:7]
df35
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 121     35      100.0        1.0     1.0  1.0      420
# 336     35      100.0        1.0     1.0  1.0       79
#
#                              model
# 121  balanced_SMOTE_ResNet_152.csv
# 336      balanced_wt_ResNet_50.csv

# %%
df36=df[(df['class']==36) & (df['total']==df['total'].max())].iloc[:,0:7]
df36
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 208     36      100.0        1.0     1.0  1.0       43
# 337     36      100.0        1.0     1.0  1.0       49
# 423     36      100.0        1.0     1.0  1.0       49
# 466     36      100.0        1.0     1.0  1.0       49
#
#                            model
# 208  balanced_tk_ResNet50_50.csv
# 337    balanced_wt_ResNet_50.csv
# 423           imbalanced_cnn.csv
# 466    imbalanced_resnet_L50.csv

# %%
df37=df[(df['class']==37) & (df['total']==df['total'].max())].iloc[:,0:7]
df37
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 295     37      100.0        1.0     1.0  1.0       44
# 338     37      100.0        1.0     1.0  1.0       44
# 424     37      100.0        1.0     1.0  1.0       44
# 467     37      100.0        1.0     1.0  1.0       44
#
#                          model
# 295        balanced_WT_cnn.csv
# 338  balanced_wt_ResNet_50.csv
# 424         imbalanced_cnn.csv
# 467  imbalanced_resnet_L50.csv

# %%
df38=df[(df['class']==38) & (df['total']==102.9154)].iloc[:,0:7]
df38
# Out:
#     class  accuraccy  precision    recall        f1  support  \
# 38     38      100.0   0.993007  0.950893  0.971494      448
#
#                      model
# 38  balanced_SMOTE_CNN.csv

# %%
df39=df[(df['class']==39) & (df['total']==df['total'].max())].iloc[:,0:7]
df39
# Out:
#      class  accuraccy  precision  recall   f1  support  \
# 125     39      100.0        1.0     1.0  1.0      416
# 297     39      100.0        1.0     1.0  1.0       88
# 340     39      100.0        1.0     1.0  1.0       88
# 426     39      100.0        1.0     1.0  1.0       88
#
#                              model
# 125  balanced_SMOTE_ResNet_152.csv
# 297            balanced_WT_cnn.csv
# 340      balanced_wt_ResNet_50.csv
# 426             imbalanced_cnn.csv

# %%
df40=df[(df['class']==40) & (df['total']==102.5217)].iloc[:,0:7]
df40
# Out:
#      class  accuraccy  precision    recall        f1  support  \
# 126     40   99.56427     0.9869  0.984749  0.985823      459
#
#                              model
# 126  balanced_SMOTE_ResNet_152.csv

# %%
df41=df[(df['class']==41) & (df['total']==102.8630)].iloc[:,0:7]
df41
# Out:
#      class  accuraccy  precision   recall        f1  support  \
# 213     41      100.0   0.968992  0.93985  0.954198      266
#
#                            model
# 213  balanced_tk_ResNet50_50.csv

# %%
df42=df[(df['class']==42) & (df['total']==102.9935)].iloc[:,0:7]
df42
# Out:
#     class  accuraccy  precision  recall        f1  support  \
# 85     42      100.0    0.99568     1.0  0.997835      461
#
#                            model
# 85  balanced_SMOTE_ResNet_50.csv

# %%
df_list=[df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42]

# %%
model_df=pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42], sort=False)

# %%
model_df
# Out:
#      class   accuraccy  precision    recall        f1  support  \
# 301      0  100.000000   1.000000  1.000000  1.000000       36
# 173      1   98.526316   0.952479  0.970526  0.961418      475
# 432      2  100.000000   0.997727  1.000000  0.998862      439
# 175      3  100.000000   0.958801  0.996109  0.977099      257
# 305      4  100.000000   1.000000  1.000000  1.000000      421
# ..     ...         ...        ...       ...       ...      ...
# 340     39  100.000000   1.000000  1.000000  1.000000       88
# 426     39  100.000000   1.000000  1.000000  1.000000       88
# 126     40   99.564270   0.986900  0.984749  0.985823      459
# 213     41  100.000000   0.968992  0.939850  0.954198      266
# 85      42  100.000000   0.995680  1.000000  0.997835      461
#
#                              model
# 301      balanced_wt_ResNet_50.csv
# 173    balanced_tk_ResNet50_50.csv
# 432      imbalanced_resnet_L50.csv
# 175    balanced_tk_ResNet50_50.csv
# ...

# %%
print(model_df.to_string())
# Out:
#      class   accuraccy  precision    recall        f1  support                          model
# 301      0  100.000000   1.000000  1.000000  1.000000       36      balanced_wt_ResNet_50.csv
# 173      1   98.526316   0.952479  0.970526  0.961418      475    balanced_tk_ResNet50_50.csv
# 432      2  100.000000   0.997727  1.000000  0.998862      439      imbalanced_resnet_L50.csv
# 175      3  100.000000   0.958801  0.996109  0.977099      257    balanced_tk_ResNet50_50.csv
# 305      4  100.000000   1.000000  1.000000  1.000000      421      balanced_wt_ResNet_50.csv
# 434      4  100.000000   1.000000  1.000000  1.000000      421      imbalanced_resnet_L50.csv
# 306      5  100.000000   1.000000  1.000000  1.000000      432      balanced_wt_ResNet_50.csv
# 92       6  100.000000   1.000000  1.000000  1.000000      475  balanced_SMOTE_ResNet_152.csv
# 135      6  100.000000   1.000000  1.000000  1.000000      169            balanced_tk_cnn.csv
# ...

# %%
model_df.model.value_counts()
# Out:
# balanced_wt_ResNet_50.csv        23
# imbalanced_cnn.csv               11
# balanced_SMOTE_CNN.csv           11
# imbalanced_resnet_L50.csv        10
# balanced_tk_ResNet50_50.csv       8
# balanced_SMOTE_ResNet_152.csv     7
# balanced_tk_cnn.csv               7
# balanced_SMOTE_ResNet_50.csv      7
# balanced_WT_cnn.csv               5
# balanced_tk_ResNet50_152.csv      3
# imbalanced_RESNET_152.csv         3
# Name: model, dtype: int64
