# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import glob
path='/content/drive/MyDrive/DBDA_PROJECT/img_rotation/'
all_files=glob.glob(path+"*.csv")

# %%
all_files
# Out:
# ['/content/drive/MyDrive/DBDA_PROJECT/img_rotation/imbalanced_cnn.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/imbalanced_resnet_50.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_SMOTE_CNN.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_SMOTE_ResNet_152.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_SMOTE_ResNet_50.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_WT_cnn.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_wt_ResNet_152.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_wt_ResNet_50.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/imbalanced_resnet_L50.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_tk_ResNet50_152.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_tk_cnn.csv',
#  '/content/drive/MyDrive/DBDA_PROJECT/img_rotation/balanced_tk_ResNet50_50.csv']

# %%
df = pd.DataFrame()
for file_ in all_files:
    file_df = pd.read_csv(file_,sep=',', parse_dates=[0], infer_datetime_format=True,header=None,skiprows=1 )
    file_df['model'] = file_
    df = df.append(file_df)

# %%
df
# Out:
#      0           1           2           3  \
# 0    0   91.666667   91.666667   91.666667
# 1    1   96.255507   96.255507   96.255507
# 2    2  100.000000  100.000000  100.000000
# 3    3   98.113208   98.113208   98.113208
# 4    4   99.049881   99.049881   99.049881
# ..  ..         ...         ...         ...
# 38  38   97.354497   97.354497   97.354497
# 39  39   95.180723   95.180723   95.180723
# 40  40   97.872340   97.872340   97.872340
# 41  41   98.120301   98.120301   98.120301
# 42  42   99.346405   99.346405   99.346405
#
#                                                 model
# 0   /content/drive/MyDrive/DBDA_PROJECT/img_rotati...
# 1   /content/drive/MyDrive/DBDA_PROJECT/img_rotati...
# 2   /content/drive/MyDrive/DBDA_PROJECT/img_rotati...
# 3   /content/drive/MyDrive/DBDA_PROJECT/img_rotati...
# 4   /content/drive/MyDrive/DBDA_PROJECT/img_rotati...
# ..                                                ...
# 38  /content/drive/MyDrive/DBDA_PROJECT/img_rotati...
# ...

# %%
df.columns =['class', 'clockwise_90', 'anticlockwise_90', '180_rotation','model']

# %%
def get_filename(path):
    temp_str = path.split('/')
    return temp_str[-1]

# %%
df["model"] = df["model"].apply(get_filename)

# %%
# saving concat data to csv
df.to_csv("/content/drive/MyDrive/DBDA_PROJECT/img_rotation/totalG.csv",index=False)

# %%
df=pd.read_csv("/content/drive/MyDrive/DBDA_PROJECT/img_rotation/totalG.csv")

# %%
df
# Out:
#      class   precision      recall          f1                        model
# 0        0   91.666667   91.666667   91.666667           imbalanced_cnn.csv
# 1        1   96.255507   96.255507   96.255507           imbalanced_cnn.csv
# 2        2  100.000000  100.000000  100.000000           imbalanced_cnn.csv
# 3        3   98.113208   98.113208   98.113208           imbalanced_cnn.csv
# 4        4   99.049881   99.049881   99.049881           imbalanced_cnn.csv
# ..     ...         ...         ...         ...                          ...
# 511     38   97.354497   97.354497   97.354497  balanced_tk_ResNet50_50.csv
# 512     39   95.180723   95.180723   95.180723  balanced_tk_ResNet50_50.csv
# 513     40   97.872340   97.872340   97.872340  balanced_tk_ResNet50_50.csv
# 514     41   98.120301   98.120301   98.120301  balanced_tk_ResNet50_50.csv
# 515     42   99.346405   99.346405   99.346405  balanced_tk_ResNet50_50.csv
#
# [516 rows x 5 columns]

# %%
df['total'] = df['clockwise_90']+df['anticlockwise_90'] + df['180_rotation']

# %%
df.total = df.total.round(2)

# %%
z=df.groupby('class',sort=False)['total'].max()
z
# Out:
# class
# 0     300.00
# 1     296.40
# 2     300.00
# 3     300.00
# 4     300.00
# 5     300.00
# 6     300.00
# 7     300.00
# 8     300.00
# 9     300.00
# 10    300.00
# 11    300.00
# 12    300.00
# 13    300.00
# 14    300.00
# 15    300.00
# 16    300.00
# 17    300.00
# 18    300.00
# 19    299.36
# 20    300.00
# 21    300.00
# 22    300.00
# 23    297.93
# 24    300.00
# 25    300.00
# 26    300.00
# 27    300.00
# 28    300.00
# 29    300.00
# 30    300.00
# 31    300.00
# 32    300.00
# 33    300.00
# 34    299.24
# 35    300.00
# 36    300.00
# 37    300.00
# 38    293.55
# 39    300.00
# 40    298.14
# 41    300.00
# 42    299.35
# Name: total, dtype: float64

# %%
df0=df[(df['class']==0) & (df['total']==z[0].max())].iloc[:,0:8]
df0
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 43       0         100.0             100.0         100.0
# 86       0         100.0             100.0         100.0
# 172      0         100.0             100.0         100.0
# 215      0         100.0             100.0         100.0
# 301      0         100.0             100.0         100.0
#
#                             model  total
# 43       imbalanced_resnet_50.csv  300.0
# 86         balanced_SMOTE_CNN.csv  300.0
# 172  balanced_SMOTE_ResNet_50.csv  300.0
# 215           balanced_WT_cnn.csv  300.0
# 301     balanced_wt_ResNet_50.csv  300.0

# %%
df1=df[(df['class']==1) & (df['total']==z[1].max())].iloc[:,0:8]
df1
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 130      1     98.800959         98.800959     98.800959
#
#                              model  total
# 130  balanced_SMOTE_ResNet_152.csv  296.4

# %%
df2=df[(df['class']==2) & (df['total']==z[2].max())].iloc[:,0:8]
df2
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 2        2         100.0             100.0         100.0
# 303      2         100.0             100.0         100.0
#
#                          model  total
# 2           imbalanced_cnn.csv  300.0
# 303  balanced_wt_ResNet_50.csv  300.0

# %%
df3=df[(df['class']==3) & (df['total']==z[3].max())].iloc[:,0:8]
df3
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 89       3         100.0             100.0         100.0
# 304      3         100.0             100.0         100.0
# 476      3         100.0             100.0         100.0
#
#                            model  total
# 89        balanced_SMOTE_CNN.csv  300.0
# 304    balanced_wt_ResNet_50.csv  300.0
# 476  balanced_tk_ResNet50_50.csv  300.0

# %%
df4=df[(df['class']==4) & (df['total']==z[4].max())].iloc[:,0:8]
df4
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 133      4         100.0             100.0         100.0
# 305      4         100.0             100.0         100.0
#
#                              model  total
# 133  balanced_SMOTE_ResNet_152.csv  300.0
# 305      balanced_wt_ResNet_50.csv  300.0

# %%
df5=df[(df['class']==5) & (df['total']==z[5].max())].iloc[:,0:8]
df5
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 134      5         100.0             100.0         100.0
# 306      5         100.0             100.0         100.0
#
#                              model  total
# 134  balanced_SMOTE_ResNet_152.csv  300.0
# 306      balanced_wt_ResNet_50.csv  300.0

# %%
df6=df[(df['class']==6) & (df['total']==z[6].max())].iloc[:,0:8]
df6
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 6        6         100.0             100.0         100.0
# 135      6         100.0             100.0         100.0
# 178      6         100.0             100.0         100.0
# 221      6         100.0             100.0         100.0
# 307      6         100.0             100.0         100.0
# 350      6         100.0             100.0         100.0
# 393      6         100.0             100.0         100.0
# 436      6         100.0             100.0         100.0
#
#                              model  total
# 6               imbalanced_cnn.csv  300.0
# 135  balanced_SMOTE_ResNet_152.csv  300.0
# 178   balanced_SMOTE_ResNet_50.csv  300.0
# 221            balanced_WT_cnn.csv  300.0
# 307      balanced_wt_ResNet_50.csv  300.0
# 350      imbalanced_resnet_L50.csv  300.0
# 393   balanced_tk_ResNet50_152.csv  300.0
# 436            balanced_tk_cnn.csv  300.0

# %%
df7=df[(df['class']==7) & (df['total']==z[7].max())].iloc[:,0:8]
df7
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 7        7         100.0             100.0         100.0
# 93       7         100.0             100.0         100.0
# 179      7         100.0             100.0         100.0
# 480      7         100.0             100.0         100.0
#
#                             model  total
# 7              imbalanced_cnn.csv  300.0
# 93         balanced_SMOTE_CNN.csv  300.0
# 179  balanced_SMOTE_ResNet_50.csv  300.0
# 480   balanced_tk_ResNet50_50.csv  300.0

# %%
df8=df[(df['class']==8) & (df['total']==z[8].max())].iloc[:,0:8]
df8
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 8        8         100.0             100.0         100.0
# 94       8         100.0             100.0         100.0
# 137      8         100.0             100.0         100.0
# 180      8         100.0             100.0         100.0
# 223      8         100.0             100.0         100.0
# 309      8         100.0             100.0         100.0
# 352      8         100.0             100.0         100.0
# 395      8         100.0             100.0         100.0
# 438      8         100.0             100.0         100.0
#
#                              model  total
# 8               imbalanced_cnn.csv  300.0
# 94          balanced_SMOTE_CNN.csv  300.0
# 137  balanced_SMOTE_ResNet_152.csv  300.0
# 180   balanced_SMOTE_ResNet_50.csv  300.0
# 223            balanced_WT_cnn.csv  300.0
# 309      balanced_wt_ResNet_50.csv  300.0
# 352      imbalanced_resnet_L50.csv  300.0
# 395   balanced_tk_ResNet50_152.csv  300.0
# ...

# %%
df9=df[(df['class']==9) & (df['total']==z[9].max())].iloc[:,0:5]
df9
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 9        9         100.0             100.0         100.0
# 52       9         100.0             100.0         100.0
# 95       9         100.0             100.0         100.0
# 138      9         100.0             100.0         100.0
# 181      9         100.0             100.0         100.0
# 224      9         100.0             100.0         100.0
# 310      9         100.0             100.0         100.0
# 353      9         100.0             100.0         100.0
# 439      9         100.0             100.0         100.0
# 482      9         100.0             100.0         100.0
#
#                              model
# 9               imbalanced_cnn.csv
# 52        imbalanced_resnet_50.csv
# 95          balanced_SMOTE_CNN.csv
# 138  balanced_SMOTE_ResNet_152.csv
# 181   balanced_SMOTE_ResNet_50.csv
# 224            balanced_WT_cnn.csv
# 310      balanced_wt_ResNet_50.csv
# 353      imbalanced_resnet_L50.csv
# ...

# %%
df10=df[(df['class']==10) & (df['total']==z[10].max())].iloc[:,0:8]
df10
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 483     10         100.0             100.0         100.0
#
#                            model  total
# 483  balanced_tk_ResNet50_50.csv  300.0

# %%
df11=df[(df['class']==11) & (df['total']==z[11].max())].iloc[:,0:8]
df11
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 183     11         100.0             100.0         100.0
# 226     11         100.0             100.0         100.0
# 312     11         100.0             100.0         100.0
# 355     11         100.0             100.0         100.0
# 398     11         100.0             100.0         100.0
# 441     11         100.0             100.0         100.0
# 484     11         100.0             100.0         100.0
#
#                             model  total
# 183  balanced_SMOTE_ResNet_50.csv  300.0
# 226           balanced_WT_cnn.csv  300.0
# 312     balanced_wt_ResNet_50.csv  300.0
# 355     imbalanced_resnet_L50.csv  300.0
# 398  balanced_tk_ResNet50_152.csv  300.0
# 441           balanced_tk_cnn.csv  300.0
# 484   balanced_tk_ResNet50_50.csv  300.0

# %%
df12=df[(df['class']==12) & (df['total']==z[12].max())].iloc[:,0:8]
df12
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 356     12         100.0             100.0         100.0
# 442     12         100.0             100.0         100.0
#
#                          model  total
# 356  imbalanced_resnet_L50.csv  300.0
# 442        balanced_tk_cnn.csv  300.0

# %%
df13=df[(df['class']==13) & (df['total']==z[13].max())].iloc[:,0:8]
df13
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 314     13         100.0             100.0         100.0
#
#                          model  total
# 314  balanced_wt_ResNet_50.csv  300.0

# %%
df14=df[(df['class']==14) & (df['total']==z[14].max())].iloc[:,0:8]
df14
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 100     14         100.0             100.0         100.0
#
#                       model  total
# 100  balanced_SMOTE_CNN.csv  300.0

# %%
df15=df[(df['class']==15) & (df['total']==z[15].max())].iloc[:,0:8]
df15
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 15      15         100.0             100.0         100.0
# 101     15         100.0             100.0         100.0
# 144     15         100.0             100.0         100.0
# 187     15         100.0             100.0         100.0
# 230     15         100.0             100.0         100.0
# 316     15         100.0             100.0         100.0
# 359     15         100.0             100.0         100.0
# 402     15         100.0             100.0         100.0
# 445     15         100.0             100.0         100.0
#
#                              model  total
# 15              imbalanced_cnn.csv  300.0
# 101         balanced_SMOTE_CNN.csv  300.0
# 144  balanced_SMOTE_ResNet_152.csv  300.0
# 187   balanced_SMOTE_ResNet_50.csv  300.0
# 230            balanced_WT_cnn.csv  300.0
# 316      balanced_wt_ResNet_50.csv  300.0
# 359      imbalanced_resnet_L50.csv  300.0
# 402   balanced_tk_ResNet50_152.csv  300.0
# ...

# %%
df16=df[(df['class']==16) & (df['total']==z[16].max())].iloc[:,0:8]
df16
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 403     16         100.0             100.0         100.0
#
#                             model  total
# 403  balanced_tk_ResNet50_152.csv  300.0

# %%
df17=df[(df['class']==17) & (df['total']==z[17].max())].iloc[:,0:8]
df17
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 103     17         100.0             100.0         100.0
# 189     17         100.0             100.0         100.0
# 318     17         100.0             100.0         100.0
#
#                             model  total
# 103        balanced_SMOTE_CNN.csv  300.0
# 189  balanced_SMOTE_ResNet_50.csv  300.0
# 318     balanced_wt_ResNet_50.csv  300.0

# %%
df18=df[(df['class']==18) & (df['total']==z[18].max())].iloc[:,0:8]
df18
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 18      18         100.0             100.0         100.0
# 104     18         100.0             100.0         100.0
# 319     18         100.0             100.0         100.0
#
#                          model  total
# 18          imbalanced_cnn.csv  300.0
# 104     balanced_SMOTE_CNN.csv  300.0
# 319  balanced_wt_ResNet_50.csv  300.0

# %%
df19=df[(df['class']==19) & (df['total']==z[19].max())].iloc[:,0:8]
df19
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 105     19     99.787234         99.787234     99.787234
# 148     19     99.787234         99.787234     99.787234
# 191     19     99.787234         99.787234     99.787234
#
#                              model   total
# 105         balanced_SMOTE_CNN.csv  299.36
# 148  balanced_SMOTE_ResNet_152.csv  299.36
# 191   balanced_SMOTE_ResNet_50.csv  299.36

# %%
df20=df[(df['class']==20) & (df['total']==z[20].max())].iloc[:,0:8]
df20
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 20      20         100.0             100.0         100.0
# 192     20         100.0             100.0         100.0
#
#                             model  total
# 20             imbalanced_cnn.csv  300.0
# 192  balanced_SMOTE_ResNet_50.csv  300.0

# %%
df21=df[(df['class']==21) & (df['total']==z[21].max())].iloc[:,0:8]
df21
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 150     21         100.0             100.0         100.0
# 494     21         100.0             100.0         100.0
#
#                              model  total
# 150  balanced_SMOTE_ResNet_152.csv  300.0
# 494    balanced_tk_ResNet50_50.csv  300.0

# %%
df22=df[(df['class']==22) & (df['total']==z[22].max())].iloc[:,0:8]
df22
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 151     22         100.0             100.0         100.0
#
#                              model  total
# 151  balanced_SMOTE_ResNet_152.csv  300.0

# %%
df23=df[(df['class']==23) & (df['total']==z[23].max())].iloc[:,0:8]
df23
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 324     23     99.310345         99.310345     99.310345
#
#                          model   total
# 324  balanced_wt_ResNet_50.csv  297.93

# %%
df24=df[(df['class']==24) & (df['total']==z[24].max())].iloc[:,0:8]
df24
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 497     24         100.0             100.0         100.0
#
#                            model  total
# 497  balanced_tk_ResNet50_50.csv  300.0

# %%
df25=df[(df['class']==25) & (df['total']==z[25].max())].iloc[:,0:8]
df25
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 154     25         100.0             100.0         100.0
#
#                              model  total
# 154  balanced_SMOTE_ResNet_152.csv  300.0

# %%
df26=df[(df['class']==26) & (df['total']==z[26].max())].iloc[:,0:8]
df26
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 26      26         100.0             100.0         100.0
# 69      26         100.0             100.0         100.0
# 112     26         100.0             100.0         100.0
# 155     26         100.0             100.0         100.0
# 241     26         100.0             100.0         100.0
# 327     26         100.0             100.0         100.0
# 499     26         100.0             100.0         100.0
#
#                              model  total
# 26              imbalanced_cnn.csv  300.0
# 69        imbalanced_resnet_50.csv  300.0
# 112         balanced_SMOTE_CNN.csv  300.0
# 155  balanced_SMOTE_ResNet_152.csv  300.0
# 241            balanced_WT_cnn.csv  300.0
# 327      balanced_wt_ResNet_50.csv  300.0
# 499    balanced_tk_ResNet50_50.csv  300.0

# %%
df27=df[(df['class']==27) & (df['total']==z[27].max())].iloc[:,0:8]
df27
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 27      27         100.0             100.0         100.0
# 113     27         100.0             100.0         100.0
# 199     27         100.0             100.0         100.0
# 328     27         100.0             100.0         100.0
# 371     27         100.0             100.0         100.0
# 414     27         100.0             100.0         100.0
# 457     27         100.0             100.0         100.0
# 500     27         100.0             100.0         100.0
#
#                             model  total
# 27             imbalanced_cnn.csv  300.0
# 113        balanced_SMOTE_CNN.csv  300.0
# 199  balanced_SMOTE_ResNet_50.csv  300.0
# 328     balanced_wt_ResNet_50.csv  300.0
# 371     imbalanced_resnet_L50.csv  300.0
# 414  balanced_tk_ResNet50_152.csv  300.0
# 457           balanced_tk_cnn.csv  300.0
# 500   balanced_tk_ResNet50_50.csv  300.0

# %%
df28=df[(df['class']==28) & (df['total']==z[28].max())].iloc[:,0:8]
df28
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 28      28         100.0             100.0         100.0
# 243     28         100.0             100.0         100.0
# 329     28         100.0             100.0         100.0
#
#                          model  total
# 28          imbalanced_cnn.csv  300.0
# 243        balanced_WT_cnn.csv  300.0
# 329  balanced_wt_ResNet_50.csv  300.0

# %%
df29=df[(df['class']==29) & (df['total']==z[29].max())].iloc[:,0:8]
df29
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 29      29         100.0             100.0         100.0
# 72      29         100.0             100.0         100.0
# 115     29         100.0             100.0         100.0
# 330     29         100.0             100.0         100.0
# 373     29         100.0             100.0         100.0
# 459     29         100.0             100.0         100.0
# 502     29         100.0             100.0         100.0
#
#                            model  total
# 29            imbalanced_cnn.csv  300.0
# 72      imbalanced_resnet_50.csv  300.0
# 115       balanced_SMOTE_CNN.csv  300.0
# 330    balanced_wt_ResNet_50.csv  300.0
# 373    imbalanced_resnet_L50.csv  300.0
# 459          balanced_tk_cnn.csv  300.0
# 502  balanced_tk_ResNet50_50.csv  300.0

# %%
df30=df[(df['class']==30) & (df['total']==z[30].max())].iloc[:,0:8]
df30
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 30      30         100.0             100.0         100.0
# 73      30         100.0             100.0         100.0
# 116     30         100.0             100.0         100.0
# 159     30         100.0             100.0         100.0
# 245     30         100.0             100.0         100.0
# 331     30         100.0             100.0         100.0
# 374     30         100.0             100.0         100.0
# 460     30         100.0             100.0         100.0
#
#                              model  total
# 30              imbalanced_cnn.csv  300.0
# 73        imbalanced_resnet_50.csv  300.0
# 116         balanced_SMOTE_CNN.csv  300.0
# 159  balanced_SMOTE_ResNet_152.csv  300.0
# 245            balanced_WT_cnn.csv  300.0
# 331      balanced_wt_ResNet_50.csv  300.0
# 374      imbalanced_resnet_L50.csv  300.0
# 460            balanced_tk_cnn.csv  300.0

# %%
df31=df[(df['class']==31) & (df['total']==z[31].max())].iloc[:,0:8]
df31
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 31      31         100.0             100.0         100.0
# 117     31         100.0             100.0         100.0
# 160     31         100.0             100.0         100.0
# 246     31         100.0             100.0         100.0
# 332     31         100.0             100.0         100.0
# 375     31         100.0             100.0         100.0
# 418     31         100.0             100.0         100.0
# 461     31         100.0             100.0         100.0
# 504     31         100.0             100.0         100.0
#
#                              model  total
# 31              imbalanced_cnn.csv  300.0
# 117         balanced_SMOTE_CNN.csv  300.0
# 160  balanced_SMOTE_ResNet_152.csv  300.0
# 246            balanced_WT_cnn.csv  300.0
# 332      balanced_wt_ResNet_50.csv  300.0
# 375      imbalanced_resnet_L50.csv  300.0
# 418   balanced_tk_ResNet50_152.csv  300.0
# 461            balanced_tk_cnn.csv  300.0
# ...

# %%
df32=df[(df['class']==32) & (df['total']==z[32].max())].iloc[:,0:8]
df32
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 32      32         100.0             100.0         100.0
# 75      32         100.0             100.0         100.0
# 118     32         100.0             100.0         100.0
# 333     32         100.0             100.0         100.0
# 419     32         100.0             100.0         100.0
#
#                             model  total
# 32             imbalanced_cnn.csv  300.0
# 75       imbalanced_resnet_50.csv  300.0
# 118        balanced_SMOTE_CNN.csv  300.0
# 333     balanced_wt_ResNet_50.csv  300.0
# 419  balanced_tk_ResNet50_152.csv  300.0

# %%
df33=df[(df['class']==33) & (df['total']==z[33].max())].iloc[:,0:8]
df33
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 76      33         100.0             100.0         100.0
# 119     33         100.0             100.0         100.0
# 205     33         100.0             100.0         100.0
# 334     33         100.0             100.0         100.0
# 377     33         100.0             100.0         100.0
# 420     33         100.0             100.0         100.0
# 463     33         100.0             100.0         100.0
# 506     33         100.0             100.0         100.0
#
#                             model  total
# 76       imbalanced_resnet_50.csv  300.0
# 119        balanced_SMOTE_CNN.csv  300.0
# 205  balanced_SMOTE_ResNet_50.csv  300.0
# 334     balanced_wt_ResNet_50.csv  300.0
# 377     imbalanced_resnet_L50.csv  300.0
# 420  balanced_tk_ResNet50_152.csv  300.0
# 463           balanced_tk_cnn.csv  300.0
# 506   balanced_tk_ResNet50_50.csv  300.0

# %%
df34=df[(df['class']==34) & (df['total']==z[34].max())].iloc[:,0:8]
df34
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 34      34     99.746835         99.746835     99.746835
# 335     34     99.746835         99.746835     99.746835
#
#                          model   total
# 34          imbalanced_cnn.csv  299.24
# 335  balanced_wt_ResNet_50.csv  299.24

# %%
df35=df[(df['class']==35) & (df['total']==z[35].max())].iloc[:,0:8]
df35
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 35      35         100.0             100.0         100.0
# 78      35         100.0             100.0         100.0
# 121     35         100.0             100.0         100.0
# 250     35         100.0             100.0         100.0
# 336     35         100.0             100.0         100.0
# 379     35         100.0             100.0         100.0
# 465     35         100.0             100.0         100.0
#
#                          model  total
# 35          imbalanced_cnn.csv  300.0
# 78    imbalanced_resnet_50.csv  300.0
# 121     balanced_SMOTE_CNN.csv  300.0
# 250        balanced_WT_cnn.csv  300.0
# 336  balanced_wt_ResNet_50.csv  300.0
# 379  imbalanced_resnet_L50.csv  300.0
# 465        balanced_tk_cnn.csv  300.0

# %%
df36=df[(df['class']==36) & (df['total']==z[36].max())].iloc[:,0:8]
df36
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 36      36         100.0             100.0         100.0
# 79      36         100.0             100.0         100.0
# 122     36         100.0             100.0         100.0
# 165     36         100.0             100.0         100.0
# 208     36         100.0             100.0         100.0
# 251     36         100.0             100.0         100.0
# 337     36         100.0             100.0         100.0
# 380     36         100.0             100.0         100.0
# 423     36         100.0             100.0         100.0
# 466     36         100.0             100.0         100.0
#
#                              model  total
# 36              imbalanced_cnn.csv  300.0
# 79        imbalanced_resnet_50.csv  300.0
# 122         balanced_SMOTE_CNN.csv  300.0
# 165  balanced_SMOTE_ResNet_152.csv  300.0
# 208   balanced_SMOTE_ResNet_50.csv  300.0
# 251            balanced_WT_cnn.csv  300.0
# ...

# %%
df37=df[(df['class']==37) & (df['total']==z[37].max())].iloc[:,0:8]
df37
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 37      37         100.0             100.0         100.0
# 123     37         100.0             100.0         100.0
# 166     37         100.0             100.0         100.0
# 252     37         100.0             100.0         100.0
# 295     37         100.0             100.0         100.0
# 338     37         100.0             100.0         100.0
#
#                              model  total
# 37              imbalanced_cnn.csv  300.0
# 123         balanced_SMOTE_CNN.csv  300.0
# 166  balanced_SMOTE_ResNet_152.csv  300.0
# 252            balanced_WT_cnn.csv  300.0
# 295     balanced_wt_ResNet_152.csv  300.0
# 338      balanced_wt_ResNet_50.csv  300.0

# %%
df38=df[(df['class']==38) & (df['total']==z[38].max())].iloc[:,0:8]
df38
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 339     38     97.849462         97.849462     97.849462
#
#                          model   total
# 339  balanced_wt_ResNet_50.csv  293.55

# %%
df39=df[(df['class']==39) & (df['total']==z[39].max())].iloc[:,0:8]
df39
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 39      39         100.0             100.0         100.0
# 82      39         100.0             100.0         100.0
# 125     39         100.0             100.0         100.0
# 211     39         100.0             100.0         100.0
# 254     39         100.0             100.0         100.0
# 340     39         100.0             100.0         100.0
# 383     39         100.0             100.0         100.0
# 469     39         100.0             100.0         100.0
#
#                             model  total
# 39             imbalanced_cnn.csv  300.0
# 82       imbalanced_resnet_50.csv  300.0
# 125        balanced_SMOTE_CNN.csv  300.0
# 211  balanced_SMOTE_ResNet_50.csv  300.0
# 254           balanced_WT_cnn.csv  300.0
# 340     balanced_wt_ResNet_50.csv  300.0
# 383     imbalanced_resnet_L50.csv  300.0
# 469           balanced_tk_cnn.csv  300.0

# %%
df40=df[(df['class']==40) & (df['total']==z[40].max())].iloc[:,0:8]
df40
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 341     40     99.378882         99.378882     99.378882
#
#                          model   total
# 341  balanced_wt_ResNet_50.csv  298.14

# %%
df41=df[(df['class']==41) & (df['total']==z[41].max())].iloc[:,0:8]
df41
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 342     41         100.0             100.0         100.0
#
#                          model  total
# 342  balanced_wt_ResNet_50.csv  300.0

# %%
df42=df[(df['class']==42) & (df['total']==z[42].max())].iloc[:,0:8]
df42
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 214     42      99.78308          99.78308      99.78308
#
#                             model   total
# 214  balanced_SMOTE_ResNet_50.csv  299.35

# %%
df_list=[df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42]

# %%
model_df=pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42], sort=False)

# %%
model_df
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation  \
# 43       0    100.000000        100.000000    100.000000
# 86       0    100.000000        100.000000    100.000000
# 172      0    100.000000        100.000000    100.000000
# 215      0    100.000000        100.000000    100.000000
# 301      0    100.000000        100.000000    100.000000
# ..     ...           ...               ...           ...
# 383     39    100.000000        100.000000    100.000000
# 469     39    100.000000        100.000000    100.000000
# 341     40     99.378882         99.378882     99.378882
# 342     41    100.000000        100.000000    100.000000
# 214     42     99.783080         99.783080     99.783080
#
#                             model   total
# 43       imbalanced_resnet_50.csv  300.00
# 86         balanced_SMOTE_CNN.csv  300.00
# 172  balanced_SMOTE_ResNet_50.csv  300.00
# 215           balanced_WT_cnn.csv  300.00
# 301     balanced_wt_ResNet_50.csv  300.00
# ...

# %%
print(model_df.to_string())
# Out:
#      class  clockwise_90  anticlockwise_90  180_rotation                          model   total
# 43       0    100.000000        100.000000    100.000000       imbalanced_resnet_50.csv  300.00
# 86       0    100.000000        100.000000    100.000000         balanced_SMOTE_CNN.csv  300.00
# 172      0    100.000000        100.000000    100.000000   balanced_SMOTE_ResNet_50.csv  300.00
# 215      0    100.000000        100.000000    100.000000            balanced_WT_cnn.csv  300.00
# 301      0    100.000000        100.000000    100.000000      balanced_wt_ResNet_50.csv  300.00
# 130      1     98.800959         98.800959     98.800959  balanced_SMOTE_ResNet_152.csv  296.40
# 2        2    100.000000        100.000000    100.000000             imbalanced_cnn.csv  300.00
# 303      2    100.000000        100.000000    100.000000      balanced_wt_ResNet_50.csv  300.00
# 89       3    100.000000        100.000000    100.000000         balanced_SMOTE_CNN.csv  300.00
# ...

# %%
model_df.model.value_counts()
# Out:
# balanced_wt_ResNet_50.csv        30
# balanced_SMOTE_CNN.csv           21
# imbalanced_cnn.csv               20
# balanced_SMOTE_ResNet_152.csv    16
# balanced_SMOTE_ResNet_50.csv     15
# balanced_WT_cnn.csv              14
# imbalanced_resnet_L50.csv        14
# balanced_tk_cnn.csv              14
# balanced_tk_ResNet50_50.csv      12
# imbalanced_resnet_50.csv         10
# balanced_tk_ResNet50_152.csv     10
# balanced_wt_ResNet_152.csv        1
# Name: model, dtype: int64
